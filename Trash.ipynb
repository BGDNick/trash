# %% [markdown]
# <a href="https://colab.research.google.com/github/BGDNick/trash/blob/main/Trash.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Dataset download

# %%
# !pip -q install gdown

# %%
import gdown

file_url = 'https://drive.google.com/file/d/1x0Iujz9q-OLf_0AGcVkJg9g7ndMvI5gH/view?usp=sharing'
file_id = file_url.split('/')[-2]
output_file = 'dataset.zip'  # Specify the name of the output file
gdown.download(f'https://drive.google.com/uc?id={file_id}', output_file)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1x0Iujz9q-OLf_0AGcVkJg9g7ndMvI5gH
# To: /content/dataset.zip
# 100%|██████████| 69.3M/69.3M [00:02<00:00, 29.3MB/s]
# 'dataset.zip'

# %%
# !unzip -q dataset.zip

# %% [markdown]
# # YOLO

# %%
# !pip -q install ultralytics
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 587.4/587.4 kB 10.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 205.1/205.1 kB 25.3 MB/s eta 0:00:00

# %%
import cv2
import numpy as np
from ultralytics import YOLO

# %%
model = YOLO()
# Out:
# ...
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 80.8MB/s]

# %%
# !ls custom_dataset
# Out:
# custom_data.yaml  test	train  valid

# %%
model.train(data='custom_dataset/custom_data.yaml', epochs=30, workers=1, imgsz=1280)
# Out:
# Ultralytics YOLOv8.0.106 🚀 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# # Model Performance

# %%
from IPython.display import Image

# %%
Image(filename='runs/detect/train3/confusion_matrix.png', width=600)

# %%
Image(filename='runs/detect/train3/results.png', width=600)

# %%
Image(filename='runs/detect/train3/val_batch0_pred.jpg', width=600)

# %% [markdown]
# # Download Pretrained model

# %%
import gdown

file_url = 'https://drive.google.com/file/d/1BVq20XCFwxJ-mOJop74-RkKW268nBk6A/view?usp=sharing'
file_id = file_url.split('/')[-2]
output_file = 'model.pt'  # Specify the name of the output file
gdown.download(f'https://drive.google.com/uc?id={file_id}', output_file)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1BVq20XCFwxJ-mOJop74-RkKW268nBk6A
# To: /content/model.pt
# 100%|██████████| 6.40M/6.40M [00:00<00:00, 12.0MB/s]
# 'model.pt'

# %%
model = YOLO('./model.pt')
